# %%
print('Hello')

print('Hello', 'deham14')

print('Hello' + 'deham14')

#Variables
cohort=14
print(cohort)
print(type(cohort))

cohort="14"
print(cohort)
print(type(cohort))

#Calculations in Python
1+1

"1" + "1" #Concatenation - these are Strings, therefore no SUM

#print(1+"hello") #This will give an error - can't add string to an integer - need to convert to similar values first

print(str(1)+"hello") #This will work - it is called type casting

14-2 #Subtraction

14/2 #Division

14*2 #Multiplication

a='12.345'
print(a)
print(type(a))
b=float(a)
print(b)
print(type(b))

print (round(14.6))

a=20
print(1+a)

vowel='a'
print(type(vowel))

print(".............................................")
print("...........Welcome to Python learning........")
print(".............................................")

myValue=True
print(type(myValue))

myValue=int(True)
print(type(myValue))
print(myValue)

myValue=int(True)
print(type(myValue))
print(str(myValue) + "is of data type" + str(type(myValue)))


#Exercise 2: String Concatenation
firstString="water"
secondString="fall"

thirdString=firstString+secondString
thirdString="fall"

print(thirdString)


"""
Your module description
"""

myFruitList = ["apple", "banana", "cherry"]
print(myFruitList)
print(type(myFruitList))

print(myFruitList[0])
print(myFruitList[1])
print(myFruitList[2])

myFruitList[2] = "orange"

print(myFruitList)

myFinalAnswerTuple = ("apple", "banana", "pineapple")
print(myFinalAnswerTuple)
print(type(myFinalAnswerTuple))

print(myFinalAnswerTuple[0])

print(myFinalAnswerTuple[1])

print(myFinalAnswerTuple[2])

myFavoriteFruitDictionary = {
    "Akua" : "apple",
    "Saanvi" : "banana",
    "Paulo" : "pineapple"
}

print(myFavoriteFruitDictionary)

print(type(myFavoriteFruitDictionary))

print(myFavoriteFruitDictionary["Akua"])

print(myFavoriteFruitDictionary["Saanvi"])

print(myFavoriteFruitDictionary["Paulo"])


#ask for a name
name = input ("What is your name? ")
print("Hello", name)
print(type(name))


#add validation for input
while True:
    name = input ("What is your name? ")
    if name.isalpha():
        print("Valid Input")
        break
    else:
        print("Invalid Input. Please enter a valid Name.")


#other form:
testresult=False

while testresult == False:
    name = input ("What is your name? ")
    if name.isalpha():
        print("Valid Input")
        testresult=True
    else:
        print("Invalid Input. Please enter a valid Name.")



a = 5
print(a)

a = 5
print(a + 12)

a +=5
print(a + 12)

b=0
b += 5
# a=a+5
print(b + 12)

#is thero because 5 - 5
b -= 5
print(b)

b %= 5 # b = b % 5 
print(b)

#Compile-time Binding, already defining data types before running program
#int a = 0

#Runtime Binding - data type will be supplied when program runs
a = "ten"

#Division Example:
try:
    c = 5
    d = int(input("Enter a non zero number: ")) #Typecasting
    result = c/d
    print(f"The result of {c} divided by {d} is {result}")
except ValueError:
    print("Invalid input. Please enter a number.")
except ZeroDivisionError:
    print("Cannot divide by zero. Please enter a non zero number.")


#Exception Handling try/except python all erorrs
import traceback
import logging

try: 
    c = 5
    d = int(input("Enter a non zero number: ")) #Typecasting
    result = c/d
    print(f"The result of {c} divided by {d} is {result}")
except Exception as e:
    print("Sorry !!!!!")


#Dictionary Data Type

myFavoriteFruitDictionary = {
    "りんご" : "apple",
    "バナナ" : "banana",
    "パイナップル" : "pineapple"
}

print(myFavoriteFruitDictionary)
print(type(myFavoriteFruitDictionary))

print(myFavoriteFruitDictionary["りんご"])
print(myFavoriteFruitDictionary["バナナ"])
print(myFavoriteFruitDictionary["パイナップル"])


userReply = input("Do you need to ship a package? (Enter yes or no)")

if userReply.upper() == "YES" or userReply.upper() == "Y": # Yes = YES
    print("We can help you ship that package!")
else:
    print("Please come back when you need to ship a package. Thank you.")
# Out:
# Hello
# Hello deham14
# Hellodeham14
# 14
# <class 'int'>
# 14
# <class 'str'>
# 1hello
# 12.345
# <class 'str'>
# 12.345
# <class 'float'>
# 15
# 21
# <class 'str'>
# .............................................
# ...........Welcome to Python learning........
# .............................................
# <class 'bool'>
# <class 'int'>
# 1
# <class 'int'>
# 1is of data type<class 'int'>
# fall
# ['apple', 'banana', 'cherry']
# <class 'list'>
# apple
# banana
# cherry
# ['apple', 'banana', 'orange']
# ('apple', 'banana', 'pineapple')
# <class 'tuple'>
# apple
# banana
# pineapple
# {'Akua': 'apple', 'Saanvi': 'banana', 'Paulo': 'pineapple'}
# <class 'dict'>
# apple
# banana
# pineapple
# Hello Rini
# <class 'str'>
# Valid Input
# Valid Input
# 5
# 17
# 22
# 17
# 0
# 0
# Cannot divide by zero. Please enter a non zero number.
# Sorry !!!!!
